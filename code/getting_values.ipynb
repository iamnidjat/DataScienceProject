# %%
import pandas as pd
import os
from pathlib import Path

INPUT_DIR = Path.home() / "Desktop" / "newData"
INPUT_DIR2 = Path.home() / "Desktop" / "anonymisedData"

assessments = pd.read_csv(os.path.join(INPUT_DIR2, "assessments.csv"))
courses = pd.read_csv(os.path.join(INPUT_DIR2, "courses.csv"))
vle = pd.read_csv(os.path.join(INPUT_DIR2, "vle.csv"))

def print_values(tables): # so check_tables can see this method
    for name, df in tables.items():
        print(f"\n==== {name.upper()} ====")
        print(df.head(10))

def check_tables(set):
    student_info = pd.read_csv(os.path.join(INPUT_DIR, f"{set}/student_info.csv"))
    student_vle = pd.read_csv(os.path.join(INPUT_DIR, f"{set}/student_vle.csv"))
    student_reg = pd.read_csv(os.path.join(INPUT_DIR, f"{set}/student_registration.csv"))
    student_assessment = pd.read_csv(os.path.join(INPUT_DIR, f"{set}/student_assessment.csv"))

    dfs = {
        "student_info": student_info,
        "student_vle": student_vle,
        "student_reg": student_reg,
        "student_assessment": student_assessment
    }

    print_values(dfs)

print("train set")
check_tables("train")
print("\nval set")
check_tables("val")
print("\ntest set")
check_tables("test")

dfs = {
    "assessments": assessments,
    "courses": courses,
    "vle": vle,
}

print_values(dfs)
# Out:
# train set
#
# ==== STUDENT_INFO ====
#   code_module code_presentation  id_student gender                region  \
# 0         AAA             2013J       11391      M   East Anglian Region
# 1         AAA             2013J       30268      F  North Western Region
# 2         AAA             2013J       32885      F  West Midlands Region
# 3         AAA             2013J       53025      M          North Region
# 4         AAA             2013J       58873      F   East Anglian Region
# 5         AAA             2013J       62155      F  North Western Region
# 6         AAA             2013J       65002      F   East Anglian Region
# 7         AAA             2013J       70464      F  West Midlands Region
# 8         AAA             2013J       71361      M               Ireland
# 9         AAA             2013J       74372      M   East Anglian Region
#
#              highest_education imd_band age_band  num_of_prev_attempts  \
# 0             HE Qualification  90-100%     55<=                     0
# 1        A Level or Equivalent   30-40%    35-55                     0
# 2           Lower Than A Level   50-60%     0-35                     0
# 3  Post Graduate Qualification      NaN     55<=                     0
# 4        A Level or Equivalent   20-30%     0-35                     0
# 5             HE Qualification   50-60%     0-35                     0
# 6        A Level or Equivalent   70-80%     0-35                     0
# 7        A Level or Equivalent   60-70%    35-55                     0
# 8             HE Qualification      NaN    35-55                     0
# 9        A Level or Equivalent    10-20    35-55                     0
#
#    studied_credits disability final_result
# 0              240          N         Pass
# 1               60          Y    Withdrawn
# 2               60          N         Pass
# 3               60          N         Pass
# 4               60          N         Pass
# 5               60          N         Pass
# 6               60          N    Withdrawn
# 7               60          N         Pass
# 8               60          N         Pass
# 9              150          N         Fail
#
# ==== STUDENT_VLE ====
#   code_module code_presentation  id_student  id_site  date  sum_click
# 0         AAA             2013J       30268   546652   -10          3
# 1         AAA             2013J       30268   546662   -10          2
# 2         AAA             2013J       30268   546614   -10          3
# 3         AAA             2013J       30268   546652   -10          2
# 4         AAA             2013J       32885   546681   -10          5
# 5         AAA             2013J       32885   547013   -10          1
# 6         AAA             2013J       32885   546652   -10          1
# 7         AAA             2013J       32885   546614   -10         13
# 8         AAA             2013J       32885   546652   -10          3
# 9         AAA             2013J       32885   546662   -10         22
#
# ==== STUDENT_REG ====
#   code_module code_presentation  id_student  date_registration  \
# 0         AAA             2013J       11391             -159.0
# 1         AAA             2013J       30268              -92.0
# 2         AAA             2013J       32885             -176.0
# 3         AAA             2013J       53025             -179.0
# 4         AAA             2013J       58873              -47.0
# 5         AAA             2013J       62155              -68.0
# 6         AAA             2013J       65002             -180.0
# 7         AAA             2013J       70464              -95.0
# 8         AAA             2013J       71361             -130.0
# 9         AAA             2013J       74372              -50.0
#
#    date_unregistration
# 0                  NaN
# 1                 12.0
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                 96.0
# 7                  NaN
# 8                  NaN
# 9                  NaN
#
# ==== STUDENT_ASSESSMENT ====
#    id_assessment  id_student  date_submitted  is_banked  score code_module  \
# 0           1752       11391              18          0   78.0         AAA
# 1           1752       32885              26          0   69.0         AAA
# 2           1752       53025               9          0   71.0         AAA
# 3           1752       58873              19          0   73.0         AAA
# 4           1752       62155              17          0   73.0         AAA
# 5           1752       65002              17          0   66.0         AAA
# 6           1752       70464              19          0   59.0         AAA
# 7           1752       71361              19          0   82.0         AAA
# 8           1752       74372              22          0   60.0         AAA
# 9           1752       77367              18          0   73.0         AAA
#
#   code_presentation
# 0             2013J
# 1             2013J
# 2             2013J
# 3             2013J
# 4             2013J
# 5             2013J
# 6             2013J
# 7             2013J
# 8             2013J
# 9             2013J
#
# val set
#
# ==== STUDENT_INFO ====
#   code_module code_presentation  id_student gender                region  \
# 0         AAA             2013J       31604      F     South East Region
# 1         AAA             2013J       45642      F  North Western Region
# 2         AAA             2013J       52130      F   East Anglian Region
# 3         AAA             2013J       91265      M  North Western Region
# 4         AAA             2013J      102806      M  North Western Region
# 5         AAA             2013J      104476      M               Ireland
# 6         AAA             2013J      106577      M  East Midlands Region
# 7         AAA             2013J      129955      M  West Midlands Region
# 8         AAA             2013J      141377      M     South West Region
# 9         AAA             2013J      144801      F          South Region
#
#              highest_education imd_band age_band  num_of_prev_attempts  \
# 0        A Level or Equivalent   50-60%    35-55                     0
# 1        A Level or Equivalent  90-100%     0-35                     0
# 2        A Level or Equivalent   70-80%     0-35                     0
# 3             HE Qualification    0-10%     0-35                     0
# 4        A Level or Equivalent   30-40%     0-35                     0
# 5  Post Graduate Qualification      NaN    35-55                     0
# 6           Lower Than A Level   20-30%     0-35                     0
# 7        A Level or Equivalent   50-60%     0-35                     0
# 8        A Level or Equivalent  90-100%     0-35                     0
# 9             HE Qualification   80-90%    35-55                     0
#
#    studied_credits disability final_result
# 0               60          N         Pass
# 1              120          N         Pass
# 2               90          N         Pass
# 3               60          N         Pass
# 4               60          N         Pass
# 5               60          N         Pass
# 6               60          N         Pass
# 7               60          N    Withdrawn
# 8              345          N    Withdrawn
# 9               60          N         Pass
#
# ==== STUDENT_VLE ====
#   code_module code_presentation  id_student  id_site  date  sum_click
# 0         AAA             2013J       31604   546672   -10          1
# 1         AAA             2013J       31604   547013   -10          5
# 2         AAA             2013J       31604   546871   -10          3
# 3         AAA             2013J       31604   546614   -10         11
# 4         AAA             2013J       31604   546660   -10          1
# 5         AAA             2013J       31604   546662   -10         19
# 6         AAA             2013J       31604   546879   -10          9
# 7         AAA             2013J       31604   546667   -10          4
# 8         AAA             2013J       31604   546688   -10          7
# 9         AAA             2013J      102806   546719   -10          3
#
# ==== STUDENT_REG ====
#   code_module code_presentation  id_student  date_registration  \
# 0         AAA             2013J       31604              -52.0
# 1         AAA             2013J       45642              -29.0
# 2         AAA             2013J       52130              -33.0
# 3         AAA             2013J       91265              -31.0
# 4         AAA             2013J      102806             -107.0
# 5         AAA             2013J      104476             -109.0
# 6         AAA             2013J      106577             -107.0
# 7         AAA             2013J      129955             -197.0
# 8         AAA             2013J      141377             -110.0
# 9         AAA             2013J      144801              -67.0
#
#    date_unregistration
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                135.0
# 8                129.0
# 9                  NaN
#
# ==== STUDENT_ASSESSMENT ====
#    id_assessment  id_student  date_submitted  is_banked  score code_module  \
# 0           1752       31604              17          0   72.0         AAA
# 1           1752       45642              18          0   72.0         AAA
# 2           1752       52130              19          0   72.0         AAA
# 3           1752       91265              21          0   75.0         AAA
# 4           1752      102806              19          0   80.0         AAA
# 5           1752      104476              30          0   85.0         AAA
# 6           1752      106577              18          0   57.0         AAA
# 7           1752      129955              18          0   85.0         AAA
# 8           1752      141377              54          0   45.0         AAA
# 9           1752      144801              19          0   61.0         AAA
#
#   code_presentation
# 0             2013J
# 1             2013J
# 2             2013J
# 3             2013J
# 4             2013J
# 5             2013J
# 6             2013J
# 7             2013J
# 8             2013J
# 9             2013J
#
# test set
#
# ==== STUDENT_INFO ====
#   code_module code_presentation  id_student gender                region  \
# 0         AAA             2013J       28400      F              Scotland
# 1         AAA             2013J       38053      M                 Wales
# 2         AAA             2013J       45462      M              Scotland
# 3         AAA             2013J       57506      M          South Region
# 4         AAA             2013J       59185      M   East Anglian Region
# 5         AAA             2013J       63400      M              Scotland
# 6         AAA             2013J       75091      M     South West Region
# 7         AAA             2013J      101781      M          South Region
# 8         AAA             2013J      135335      F   East Anglian Region
# 9         AAA             2013J      141355      F  East Midlands Region
#
#        highest_education imd_band age_band  num_of_prev_attempts  \
# 0       HE Qualification   20-30%    35-55                     0
# 1  A Level or Equivalent   80-90%    35-55                     0
# 2       HE Qualification   30-40%     0-35                     0
# 3     Lower Than A Level   70-80%    35-55                     0
# 4     Lower Than A Level   60-70%    35-55                     0
# 5     Lower Than A Level   40-50%    35-55                     0
# 6  A Level or Equivalent   30-40%    35-55                     0
# 7     Lower Than A Level   80-90%    35-55                     0
# 8     Lower Than A Level   20-30%     0-35                     0
# 9  A Level or Equivalent   30-40%     0-35                     0
#
#    studied_credits disability final_result
# 0               60          N         Pass
# 1               60          N         Pass
# 2               60          N         Pass
# 3               60          N         Pass
# 4               60          N         Pass
# 5               60          N         Pass
# 6               60          N         Pass
# 7               60          N         Pass
# 8              180          N    Withdrawn
# 9              240          N         Pass
#
# ==== STUDENT_VLE ====
#   code_module code_presentation  id_student  id_site  date  sum_click
# 0         AAA             2013J       28400   546652   -10          4
# 1         AAA             2013J       28400   546652   -10          1
# 2         AAA             2013J       28400   546652   -10          1
# 3         AAA             2013J       28400   546614   -10         11
# 4         AAA             2013J       28400   546714   -10          1
# 5         AAA             2013J       28400   546652   -10          8
# 6         AAA             2013J       28400   546876   -10          2
# 7         AAA             2013J       28400   546688   -10         15
# 8         AAA             2013J       28400   546662   -10         17
# 9         AAA             2013J       28400   546890   -10          1
#
# ==== STUDENT_REG ====
#   code_module code_presentation  id_student  date_registration  \
# 0         AAA             2013J       28400              -53.0
# 1         AAA             2013J       38053             -110.0
# 2         AAA             2013J       45462              -67.0
# 3         AAA             2013J       57506             -103.0
# 4         AAA             2013J       59185              -59.0
# 5         AAA             2013J       63400              -67.0
# 6         AAA             2013J       75091             -107.0
# 7         AAA             2013J      101781             -103.0
# 8         AAA             2013J      135335              -29.0
# 9         AAA             2013J      141355              -61.0
#
#    date_unregistration
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# 5                  NaN
# 6                  NaN
# 7                  NaN
# 8                 30.0
# 9                  NaN
#
# ==== STUDENT_ASSESSMENT ====
#    id_assessment  id_student  date_submitted  is_banked  score code_module  \
# 0           1752       28400              22          0   70.0         AAA
# 1           1752       38053              19          0   79.0         AAA
# 2           1752       45462              20          0   70.0         AAA
# 3           1752       57506              18          0   68.0         AAA
# 4           1752       59185              18          0   67.0         AAA
# 5           1752       63400              19          0   83.0         AAA
# 6           1752       75091              18          0   67.0         AAA
# 7           1752      101781              16          0   84.0         AAA
# 8           1752      141355              19          0   77.0         AAA
# 9           1752      146188              19          0   52.0         AAA
#
#   code_presentation
# 0             2013J
# 1             2013J
# 2             2013J
# 3             2013J
# 4             2013J
# 5             2013J
# 6             2013J
# 7             2013J
# 8             2013J
# 9             2013J
#
# ==== ASSESSMENTS ====
#   code_module code_presentation  id_assessment assessment_type   date  weight
# 0         AAA             2013J           1752             TMA   19.0    10.0
# 1         AAA             2013J           1753             TMA   54.0    20.0
# 2         AAA             2013J           1754             TMA  117.0    20.0
# 3         AAA             2013J           1755             TMA  166.0    20.0
# 4         AAA             2013J           1756             TMA  215.0    30.0
# 5         AAA             2013J           1757            Exam    NaN   100.0
# 6         AAA             2014J           1758             TMA   19.0    10.0
# 7         AAA             2014J           1759             TMA   54.0    20.0
# 8         AAA             2014J           1760             TMA  117.0    20.0
# 9         AAA             2014J           1761             TMA  166.0    20.0
#
# ==== COURSES ====
#   code_module code_presentation  module_presentation_length
# 0         AAA             2013J                         268
# 1         AAA             2014J                         269
# 2         BBB             2013J                         268
# 3         BBB             2014J                         262
# 4         BBB             2013B                         240
# 5         BBB             2014B                         234
# 6         CCC             2014J                         269
# 7         CCC             2014B                         241
# 8         DDD             2013J                         261
# 9         DDD             2014J                         262
#
# ==== VLE ====
#    id_site code_module code_presentation activity_type  week_from  week_to
# 0   546943         AAA             2013J      resource        NaN      NaN
# 1   546712         AAA             2013J     oucontent        NaN      NaN
# 2   546998         AAA             2013J      resource        NaN      NaN
# 3   546888         AAA             2013J           url        NaN      NaN
# 4   547035         AAA             2013J      resource        NaN      NaN
# 5   546614         AAA             2013J      homepage        NaN      NaN
# 6   546897         AAA             2013J           url        NaN      NaN
# 7   546678         AAA             2013J     oucontent        NaN      NaN
# 8   546933         AAA             2013J      resource        NaN      NaN
# 9   546708         AAA             2013J     oucontent        NaN      NaN
